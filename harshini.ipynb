# %%
from groq import Groq
client = Groq(api_key="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")
def chat():
    print("Chat-bot Started!\n")
    while True:
        user_input = input("User: ")
        if user_input.lower() == "exit":
            print("Closing Chat-bot..")
            break
        response = client.chat.completions.create(
            messages=[
                {"role": "system", "content": "You are a helpful assistant."},
                {"role": "user", "content": user_input}
            ],
            model="llama-3.3-70b-versatile"
        )
        reply = response.choices[0].message.content
        print("Chatbot:", reply, "\n")
if __name__ == "__main__":
    chat()
# Out:
# Chat-bot Started!
# User:  what is dta
# Chatbot: DTA can stand for several things, depending on the context:
#
# 1. **Data Transfer Agreement**: A Data Transfer Agreement (DTA) is a contract between two or more parties that governs the transfer of data, such as personal data, confidential information, or sensitive data. It outlines the terms and conditions for the transfer, including security measures, confidentiality, and compliance with relevant laws and regulations.
# 2. **Differential Thermal Analysis**: Differential Thermal Analysis (DTA) is a thermal analysis technique used to measure the heat flow associated with thermal events, such as phase transitions, reactions, or decompositions, in a material. It is commonly used in materials science, chemistry, and physics to study the thermal properties of materials.
# 3. **Dynamic Texture Analysis**: Dynamic Texture Analysis (DTA) is a technique used to analyze and understand the dynamic behavior of textures, such as those found in images or videos. It is used in computer vision, image processing, and machine learning to extract features and patterns from textures.
# 4. **Data Transmission Algorithm**: A Data Transmission Algorithm (DTA) is a set of rules or procedures used to transmit data efficiently and reliably over a communication network. It may involve techniques such as data compression, error correction, and flow control.
# 5. **Other meanings**: DTA can also stand for other things, such as "Data Transfer Agent", "Digital Transformation Agency", or "Designated Transit Area", depending on the context in which it is used.
#
# If you could provide more context or information about the DTA you are referring to, I may be able to provide a more specific and relevant answer.
